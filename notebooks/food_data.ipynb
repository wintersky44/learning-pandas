# %% [markdown]
# ### imports

# %%
# %matplotlib widget
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### dataset

# %%
df = pd.read_csv("../data/foods_dataset.csv")

# %% [markdown]
# ### analysis

# %%
df.head()
# Out:
#               restaurant_id           dish_name     category cuisine_type  \
# 0  d638fe7074e004cbe8293709      Lemon Iced Tea  Main Course        Other
# 1  d638fe7074e004cbe8293709  Chicken Manchurian      Starter      Chinese
# 2  d638fe7074e004cbe8293709         Cold Coffee     Beverage        Other
# 3  d638fe7074e004cbe8293709             Brownie      Dessert        Other
# 4  9bc75aff648e50ecb167cf64    Margherita Pizza  Main Course      Italian
#
#                    description  price  tax_gst_% food_type spice_level  \
# 0  Main Course with Mild taste    144         18     Vegan        Mild
# 1      Starter with Mild taste    130          0   Non-Veg        Mild
# 2    Beverage with Spicy taste    376          0      Jain       Spicy
# 3    Dessert with Medium taste    423         18       Veg      Medium
# 4  Main Course with Mild taste    488         18       Veg        Mild
#
#                            image_url  created_at
# ...
