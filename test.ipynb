# %% [markdown]
# ### imports

# %%
import pandas as pd

# %% [markdown]
# ### datasets

# %%
df = pd.read_csv("data/melb_data.csv")

df2 = pd.read_csv("data/toy_dataset.csv")

df2 = df2.set_index("ID")

df3 = pd.read_csv("data/mobiles.csv")

df4 = df3.drop(columns=['url','Picture URL', '1 Stars', '2 Stars', '3 Stars', '4 Stars'])

df5 = pd.read_csv("data/amazon.csv")

# %% [markdown]
# ### testing

# %%
grouped = df5.groupby('category')

grouped.groups
# Out:
# {'Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers': [1157], 'Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters': [695, 742], 'Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets': [906], 'Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones': [748, 772], 'Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers': [844, 936], 'Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|Webcams&VoIPEquipment|Webcams': [794, 877], 'Computers&Accessories|Accessories&Peripherals|Cables&Accessories|CableConnectionProtectors': [407, 602, 644], 'Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|DVICables': [230], 'Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|EthernetCables': [769, 832], 'Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|SATACables': [900], 'Computers&Accessories|Accessorie
# ...
